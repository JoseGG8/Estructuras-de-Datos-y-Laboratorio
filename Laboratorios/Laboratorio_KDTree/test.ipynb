# %% [markdown]
# Datos y construcción del árbol: Los datos se almacenan en una lista de tuplas con coordenadas (x,y) aleatorias entre 0 y 1000 generadas por la librería random

# %%
import random
from funciones_graficas import *
from KD_Tree import *

#almacenamiento de los datos#
datos = [(random.randint(0, 1000), random.randint(0, 1000)) for _ in range(10000)]

# %%
#construcción del árbol
arbol = KD_Tree(datos)
arbol.construir_arbol()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# En el gráfico creado por la ejecución de la siguiente celda se puede ver la búsqueda por radio implementada.
# El método graficar_busqueda_radio() recibe como parámetros el arbol por facilidad para implementar la lista que genera el método busqueda por radio de la clase KD_Tree, toma esta lista, crea un círculo con el parámetro radio alrededor del punto objetivo (punto a partir del cual se quiere buscar)

# %%
graficar_busqueda_radio(arbol, (400, 400), 200)

# %% [markdown]
# En el siguiente gráfico se puede ver la busqueda del vecino más cercano implementada. Recibe como parámetros el árbol y el punto objetivo, la gráfica se ajusta según la ubicación del punto para facilitar su visibilidad.

# %%
graficar_vecino_cercano(arbol, (500, 500))

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------
